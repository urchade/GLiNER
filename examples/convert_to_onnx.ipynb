# %% [markdown]
# # Export and run GLiNER with ONNX Runtime

# %%
# %pip install "gliner[onnx]" onnx

# %%
from pathlib import Path

from gliner import GLiNER

# %%
source_model = GLiNER.from_pretrained("urchade/gliner_medium")

# %%
exported = source_model.export_to_onnx(
    save_dir="gliner_medium_onnx",
    onnx_filename="model.onnx",
    quantized_filename="model_quantized.onnx",
    quantize=True,
    opset=19,
)
exported

# %%
model = GLiNER.from_pretrained(
    "gliner_medium_onnx",
    runtime="onnxruntime",
    runtime_model_file="model.onnx",
    local_files_only=True,
)

# %%
text = """
Libretto by Marius Petipa, based on the 1822 novella ``Trilby, ou Le Lutin d'Argail`` by Charles Nodier, first presented by the Ballet of the Moscow Imperial Bolshoi Theatre on January 25/February 6 (Julian/Gregorian calendar dates), 1870, in Moscow with Polina Karpakova as Trilby and Ludiia Geiten as Miranda and restaged by Petipa for the Imperial Ballet at the Imperial Bolshoi Kamenny Theatre on January 17–29, 1871 in St. Petersburg with Adèle Grantzow as Trilby and Lev Ivanov as Count Leopold.
"""
labels = ["person", "book", "location", "date", "actor", "character"]

for entity in model.predict_entities(text, labels, threshold=0.4):
    print(entity["text"], "=>", entity["label"])

# %%
# Quantization is best-effort, so only load the artifact when it was created.
quantized_model = None
if exported["quantized_path"] is not None:
    quantized_model = GLiNER.from_pretrained(
        "gliner_medium_onnx",
        runtime="onnxruntime",
        runtime_model_file=Path(exported["quantized_path"]).name,
        local_files_only=True,
    )

# %%
if quantized_model is None:
    print("Quantized model was not created.")
else:
    for entity in quantized_model.predict_entities(text, labels, threshold=0.4):
        print(entity["text"], "=>", entity["label"])
